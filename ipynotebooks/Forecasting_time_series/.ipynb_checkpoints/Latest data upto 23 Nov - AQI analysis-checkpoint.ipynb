# %%
1729
# Out:
# 1729

# %%
# Data analysis
import pandas as pd 

# Data Visualization
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px 

# Time Series
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from datetime import datetime, timedelta
from statsmodels.tsa.arima.model import ARIMA 
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
import statsmodels.api as sm

# For printing multiple outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Visualization parameters
sns.set(rc={"figure.dpi":100, 'savefig.dpi':300})
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats
# %config InlineBackend.figure_format = 'retina'

# %%
PATH = "../../data/raw_data"

# %% [markdown]
# # 1. Data cleaning, preprocessing & EDA

# %% [markdown]
# ## 1.1 Sector 51

# %%
sector_51 = pd.read_excel(PATH + "/sector_51_daily_5:3:20 to 23:11:23.xlsx")
sector_51
# Out:
#      CENTRAL POLLUTION CONTROL BOARD        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0     CONTINUOUS AMBIENT AIR QUALITY               NaN        NaN        NaN
# 1        Date: Thursday, Nov 23 2023               NaN        NaN        NaN
# 2                  Time: 12:24:26 PM               NaN        NaN        NaN
# 3                              State           Haryana        NaN        NaN
# 4                               City          Gurugram        NaN        NaN
# ...                              ...               ...        ...        ...
# 1370                19-11-2023 00:00  20-11-2023 00:00     149.81     234.32
# 1371                20-11-2023 00:00  21-11-2023 00:00     177.53     321.96
# 1372                21-11-2023 00:00  22-11-2023 00:00     150.27     222.25
# 1373                22-11-2023 00:00  23-11-2023 00:00        173      281.5
# 1374                23-11-2023 00:00  23-11-2023 00:00     256.99     803.59
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0           NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...
# 1370      16.35      15.63      20.79       1.87      10.31
# 1371       15.1      11.77      19.21       2.51      34.88
# 1372       15.1      11.78      19.21       2.27      49.94
# 1373       15.1      11.77      19.21       1.93      49.94
# 1374      15.99      14.23      16.59        5.1      34.88
#
# [1375 rows x 9 columns]

# %%
sector_51[:22]
# Out:
#    CENTRAL POLLUTION CONTROL BOARD                      Unnamed: 1 Unnamed: 2  \
# 0   CONTINUOUS AMBIENT AIR QUALITY                             NaN        NaN
# 1      Date: Thursday, Nov 23 2023                             NaN        NaN
# 2                Time: 12:24:26 PM                             NaN        NaN
# 3                            State                         Haryana        NaN
# 4                             City                        Gurugram        NaN
# 5                          Station     Sector-51, Gurugram - HSPCB        NaN
# 6                        Parameter  PM2.5,PM10,NO,NO2,NOx,CO,Ozone        NaN
# 7                        AvgPeriod                        24 Hours        NaN
# 8                             From      05-03-2020T00:00:00Z 00:00        NaN
# 9                               To      23-11-2023T00:00:59Z 00:00        NaN
# 10                             NaN                             NaN        NaN
# 11     Sector-51, Gurugram - HSPCB                             NaN        NaN
# 12            Prescribed Standards                                       0-60
# 13             Exceeding Standards                                        NaN
# 14                         Remarks                             NaN        NaN
# 15                       From Date                         To Date      PM2.5
# 16                05-03-2020 00:00                06-03-2020 00:00      36.51
# 17                06-03-2020 00:00                07-03-2020 00:00      22.23
# 18                07-03-2020 00:00                08-03-2020 00:00      41.44
# 19                08-03-2020 00:00                09-03-2020 00:00      62.64
# 20                09-03-2020 00:00                10-03-2020 00:00      83.74
# 21                10-03-2020 00:00                11-03-2020 00:00       97.3
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 12      0-100       0-80       0-80       0-80        0-4      0-180
# 13        NaN        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN        NaN
# 15       PM10         NO        NO2        NOx         CO      Ozone
# 16      73.15       5.91      24.28      30.19       0.51      71.07
# 17      39.15       5.89      23.24      29.12       0.45      55.32
# 18      77.68       8.54      21.67       30.2       0.63      46.15
# 19     130.39      18.77      24.16      42.94       0.86      41.67
# 20     127.54       4.88       22.1      26.98       0.68      49.61
# 21     159.07       5.34       23.2      28.54        0.8      62.53

# %% [markdown]
# - First 14 rows are not required, we will remove them and add 15th row as columns

# %% [markdown]
# ### 1.1.1 Removing unwanted rows

# %%
sector_51 = sector_51[15:]
sector_51
# Out:
#      CENTRAL POLLUTION CONTROL BOARD        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 15                         From Date           To Date      PM2.5       PM10
# 16                  05-03-2020 00:00  06-03-2020 00:00      36.51      73.15
# 17                  06-03-2020 00:00  07-03-2020 00:00      22.23      39.15
# 18                  07-03-2020 00:00  08-03-2020 00:00      41.44      77.68
# 19                  08-03-2020 00:00  09-03-2020 00:00      62.64     130.39
# ...                              ...               ...        ...        ...
# 1370                19-11-2023 00:00  20-11-2023 00:00     149.81     234.32
# 1371                20-11-2023 00:00  21-11-2023 00:00     177.53     321.96
# 1372                21-11-2023 00:00  22-11-2023 00:00     150.27     222.25
# 1373                22-11-2023 00:00  23-11-2023 00:00        173      281.5
# 1374                23-11-2023 00:00  23-11-2023 00:00     256.99     803.59
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 15           NO        NO2        NOx         CO      Ozone
# 16         5.91      24.28      30.19       0.51      71.07
# 17         5.89      23.24      29.12       0.45      55.32
# 18         8.54      21.67       30.2       0.63      46.15
# 19        18.77      24.16      42.94       0.86      41.67
# ...         ...        ...        ...        ...        ...
# 1370      16.35      15.63      20.79       1.87      10.31
# 1371       15.1      11.77      19.21       2.51      34.88
# 1372       15.1      11.78      19.21       2.27      49.94
# 1373       15.1      11.77      19.21       1.93      49.94
# 1374      15.99      14.23      16.59        5.1      34.88
#
# [1360 rows x 9 columns]

# %% [markdown]
# ### 1.1.2 Changing column names

# %%
columns = sector_51.iloc[0,:]
columns
# Out:
# CENTRAL POLLUTION CONTROL BOARD    From Date
# Unnamed: 1                           To Date
# Unnamed: 2                             PM2.5
# Unnamed: 3                              PM10
# Unnamed: 4                                NO
# Unnamed: 5                               NO2
# Unnamed: 6                               NOx
# Unnamed: 7                                CO
# Unnamed: 8                             Ozone
# Name: 15, dtype: object

# %%
sector_51.columns = columns
sector_51
# Out:
# 15           From Date           To Date   PM2.5    PM10     NO    NO2    NOx  \
# 15           From Date           To Date   PM2.5    PM10     NO    NO2    NOx
# 16    05-03-2020 00:00  06-03-2020 00:00   36.51   73.15   5.91  24.28  30.19
# 17    06-03-2020 00:00  07-03-2020 00:00   22.23   39.15   5.89  23.24  29.12
# 18    07-03-2020 00:00  08-03-2020 00:00   41.44   77.68   8.54  21.67   30.2
# 19    08-03-2020 00:00  09-03-2020 00:00   62.64  130.39  18.77  24.16  42.94
# ...                ...               ...     ...     ...    ...    ...    ...
# 1370  19-11-2023 00:00  20-11-2023 00:00  149.81  234.32  16.35  15.63  20.79
# 1371  20-11-2023 00:00  21-11-2023 00:00  177.53  321.96   15.1  11.77  19.21
# 1372  21-11-2023 00:00  22-11-2023 00:00  150.27  222.25   15.1  11.78  19.21
# 1373  22-11-2023 00:00  23-11-2023 00:00     173   281.5   15.1  11.77  19.21
# 1374  23-11-2023 00:00  23-11-2023 00:00  256.99  803.59  15.99  14.23  16.59
#
# 15      CO  Ozone
# 15      CO  Ozone
# 16    0.51  71.07
# 17    0.45  55.32
# 18    0.63  46.15
# 19    0.86  41.67
# ...    ...    ...
# 1370  1.87  10.31
# 1371  2.51  34.88
# 1372  2.27  49.94
# 1373  1.93  49.94
# 1374   5.1  34.88
#
# [1360 rows x 9 columns]

# %%
# Remove column name as 15
sector_51.columns.name = ""

# %% [markdown]
# ### 1.1.3 Changing index

# %%
sector_51.index
# Out:
# RangeIndex(start=15, stop=1375, step=1)

# %%
sector_51.reset_index(inplace=True)

# %%
# Need to remove index column, row 0
sector_51
# Out:
#       index         From Date           To Date   PM2.5    PM10     NO    NO2  \
# 0        15         From Date           To Date   PM2.5    PM10     NO    NO2
# 1        16  05-03-2020 00:00  06-03-2020 00:00   36.51   73.15   5.91  24.28
# 2        17  06-03-2020 00:00  07-03-2020 00:00   22.23   39.15   5.89  23.24
# 3        18  07-03-2020 00:00  08-03-2020 00:00   41.44   77.68   8.54  21.67
# 4        19  08-03-2020 00:00  09-03-2020 00:00   62.64  130.39  18.77  24.16
# ...     ...               ...               ...     ...     ...    ...    ...
# 1355   1370  19-11-2023 00:00  20-11-2023 00:00  149.81  234.32  16.35  15.63
# 1356   1371  20-11-2023 00:00  21-11-2023 00:00  177.53  321.96   15.1  11.77
# 1357   1372  21-11-2023 00:00  22-11-2023 00:00  150.27  222.25   15.1  11.78
# 1358   1373  22-11-2023 00:00  23-11-2023 00:00     173   281.5   15.1  11.77
# 1359   1374  23-11-2023 00:00  23-11-2023 00:00  256.99  803.59  15.99  14.23
#
#         NOx    CO  Ozone
# 0       NOx    CO  Ozone
# 1     30.19  0.51  71.07
# 2     29.12  0.45  55.32
# 3      30.2  0.63  46.15
# 4     42.94  0.86  41.67
# ...     ...   ...    ...
# 1355  20.79  1.87  10.31
# 1356  19.21  2.51  34.88
# 1357  19.21  2.27  49.94
# 1358  19.21  1.93  49.94
# 1359  16.59   5.1  34.88
#
# [1360 rows x 10 columns]

# %%
sector_51.drop(columns=['index'], inplace=True)
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/1384764267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51.drop(columns=['index'], inplace=True)

# %%
sector_51.drop(index=0, inplace=True)
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/1066287836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51.drop(index=0, inplace=True)

# %%
sector_51
# Out:
#              From Date           To Date   PM2.5    PM10     NO    NO2    NOx  \
# 1     05-03-2020 00:00  06-03-2020 00:00   36.51   73.15   5.91  24.28  30.19
# 2     06-03-2020 00:00  07-03-2020 00:00   22.23   39.15   5.89  23.24  29.12
# 3     07-03-2020 00:00  08-03-2020 00:00   41.44   77.68   8.54  21.67   30.2
# 4     08-03-2020 00:00  09-03-2020 00:00   62.64  130.39  18.77  24.16  42.94
# 5     09-03-2020 00:00  10-03-2020 00:00   83.74  127.54   4.88   22.1  26.98
# ...                ...               ...     ...     ...    ...    ...    ...
# 1355  19-11-2023 00:00  20-11-2023 00:00  149.81  234.32  16.35  15.63  20.79
# 1356  20-11-2023 00:00  21-11-2023 00:00  177.53  321.96   15.1  11.77  19.21
# 1357  21-11-2023 00:00  22-11-2023 00:00  150.27  222.25   15.1  11.78  19.21
# 1358  22-11-2023 00:00  23-11-2023 00:00     173   281.5   15.1  11.77  19.21
# 1359  23-11-2023 00:00  23-11-2023 00:00  256.99  803.59  15.99  14.23  16.59
#
#         CO  Ozone
# 1     0.51  71.07
# 2     0.45  55.32
# 3     0.63  46.15
# 4     0.86  41.67
# 5     0.68  49.61
# ...    ...    ...
# 1355  1.87  10.31
# 1356  2.51  34.88
# 1357  2.27  49.94
# 1358  1.93  49.94
# 1359   5.1  34.88
#
# [1359 rows x 9 columns]

# %%
# Remove to date
sector_51.drop(columns=['To Date'], inplace=True)
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/2814536546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51.drop(columns=['To Date'], inplace=True)

# %%
sector_51
# Out:
#              From Date   PM2.5    PM10     NO    NO2    NOx    CO  Ozone
# 1     05-03-2020 00:00   36.51   73.15   5.91  24.28  30.19  0.51  71.07
# 2     06-03-2020 00:00   22.23   39.15   5.89  23.24  29.12  0.45  55.32
# 3     07-03-2020 00:00   41.44   77.68   8.54  21.67   30.2  0.63  46.15
# 4     08-03-2020 00:00   62.64  130.39  18.77  24.16  42.94  0.86  41.67
# 5     09-03-2020 00:00   83.74  127.54   4.88   22.1  26.98  0.68  49.61
# ...                ...     ...     ...    ...    ...    ...   ...    ...
# 1355  19-11-2023 00:00  149.81  234.32  16.35  15.63  20.79  1.87  10.31
# 1356  20-11-2023 00:00  177.53  321.96   15.1  11.77  19.21  2.51  34.88
# 1357  21-11-2023 00:00  150.27  222.25   15.1  11.78  19.21  2.27  49.94
# 1358  22-11-2023 00:00     173   281.5   15.1  11.77  19.21  1.93  49.94
# 1359  23-11-2023 00:00  256.99  803.59  15.99  14.23  16.59   5.1  34.88
#
# [1359 rows x 8 columns]

# %%
# Set index 
sector_51.set_index(sector_51['From Date'], inplace=True)

# %%
# Remove from date
sector_51.drop(columns=['From Date'], inplace=True)
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/1583486620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51.drop(columns=['From Date'], inplace=True)

# %%
sector_51
# Out:
#                    PM2.5    PM10     NO    NO2    NOx    CO  Ozone
# From Date
# 05-03-2020 00:00   36.51   73.15   5.91  24.28  30.19  0.51  71.07
# 06-03-2020 00:00   22.23   39.15   5.89  23.24  29.12  0.45  55.32
# 07-03-2020 00:00   41.44   77.68   8.54  21.67   30.2  0.63  46.15
# 08-03-2020 00:00   62.64  130.39  18.77  24.16  42.94  0.86  41.67
# 09-03-2020 00:00   83.74  127.54   4.88   22.1  26.98  0.68  49.61
# ...                  ...     ...    ...    ...    ...   ...    ...
# 19-11-2023 00:00  149.81  234.32  16.35  15.63  20.79  1.87  10.31
# 20-11-2023 00:00  177.53  321.96   15.1  11.77  19.21  2.51  34.88
# 21-11-2023 00:00  150.27  222.25   15.1  11.78  19.21  2.27  49.94
# 22-11-2023 00:00     173   281.5   15.1  11.77  19.21  1.93  49.94
# 23-11-2023 00:00  256.99  803.59  15.99  14.23  16.59   5.1  34.88
#
# [1359 rows x 7 columns]

# %% [markdown]
# ### 1.1.4 Changing data types

# %%
sector_51.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 05-03-2020 00:00 to 23-11-2023 00:00
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PM2.5   1359 non-null   object
#  1   PM10    1359 non-null   object
#  2   NO      1359 non-null   object
#  3   NO2     1359 non-null   object
#  4   NOx     1359 non-null   object
#  5   CO      1359 non-null   object
#  6   Ozone   1359 non-null   object
# dtypes: object(7)
# memory usage: 84.9+ KB

# %%
sector_51.index = pd.to_datetime(sector_51.index)

# %%
sector_51
# Out:
#              PM2.5    PM10     NO    NO2    NOx    CO  Ozone
# From Date
# 2020-05-03   36.51   73.15   5.91  24.28  30.19  0.51  71.07
# 2020-06-03   22.23   39.15   5.89  23.24  29.12  0.45  55.32
# 2020-07-03   41.44   77.68   8.54  21.67   30.2  0.63  46.15
# 2020-08-03   62.64  130.39  18.77  24.16  42.94  0.86  41.67
# 2020-09-03   83.74  127.54   4.88   22.1  26.98  0.68  49.61
# ...            ...     ...    ...    ...    ...   ...    ...
# 2023-11-19  149.81  234.32  16.35  15.63  20.79  1.87  10.31
# 2023-11-20  177.53  321.96   15.1  11.77  19.21  2.51  34.88
# 2023-11-21  150.27  222.25   15.1  11.78  19.21  2.27  49.94
# 2023-11-22     173   281.5   15.1  11.77  19.21  1.93  49.94
# 2023-11-23  256.99  803.59  15.99  14.23  16.59   5.1  34.88
#
# [1359 rows x 7 columns]

# %%
sector_51.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'CO', 'Ozone'], dtype='object', name='')

# %%
for column in sector_51.columns:
    try:
        sector_51[column] = pd.to_numeric(sector_51[column])
        print(column + " has successfully been converted into float.")
    except:
        print(column + " has None values, please deal with it and then convert into float.")
# Out:
# PM2.5 has successfully been converted into float.
# PM10 has successfully been converted into float.
# NO has None values, please deal with it and then convert into float.
# NO2 has None values, please deal with it and then convert into float.
# NOx has successfully been converted into float.
# CO has successfully been converted into float.
# Ozone has successfully been converted into float.
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/3563351487.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51[column] = pd.to_numeric(sector_51[column])

# %% [markdown]
# - NO and NO2 have None values, so need to clean them first and then convert it into float.

# %% [markdown]
# ### 1.1.5 Dealing with missing/None values

# %% [markdown]
# #### 1.1.5.1 NO column

# %%
sector_51.isna().sum()
# Out:
# From Date    0
# PM2.5        0
# PM10         0
# NO           0
# NO2          0
# NOx          0
# CO           0
# Ozone        0
# dtype: int64

# %% [markdown]
# - This shows 0, but we have None in NO & NO2

# %%
sector_51['NO'].value_counts(dropna=False)
# Out:
# None    17
# 7.99     6
# 3        6
# 4.35     5
# 8.02     5
#         ..
# 5.59     1
# 9.64     1
# 9.38     1
# 9.72     1
# 12.9     1
# Name: NO, Length: 993, dtype: int64

# %%
sector_51.value_counts(dropna=False)
# Out:
# PM2.5   PM10    NO     NO2    NOx    CO    Ozone
# 10.32   16.37   13.43  3.27   10.50  0.32  32.18    1
# 117.98  187.33  3.10   6.45   2.67   0.48  32.44    1
# 119.38  190.76  7.14   17.97  26.48  0.83  21.61    1
# 119.29  298.77  2.55   8.45   15.01  0.69  20.06    1
# 119.26  189.39  8.60   8.72   12.63  0.34  35.82    1
#                                                    ..
# 65.66   104.23  5.22   21.59  13.02  0.30  34.62    1
# 65.61   111.51  6.11   12.33  11.84  0.63  23.07    1
# 65.49   177.74  3.87   2.53   3.37   0.57  16.95    1
# 65.46   103.91  29.82  16.50  26.41  1.03  35.21    1
# 560.22  859.34  49.79  55.27  30.88  4.07  4.98     1
# Length: 1359, dtype: int64

# %%
# find index of None values
sector_51[sector_51['NO'] == "None"]
# Out:
#              PM2.5    PM10    NO    NO2   NOx    CO   Ozone
# From Date
# 2020-06-06   49.62  136.84  None  14.11  6.09  0.54   97.52
# 2020-07-06   52.24  116.21  None  13.59  5.75  0.54  102.20
# 2020-09-06   67.59  149.46  None  14.25  5.94  0.67  104.55
# 2020-12-06   79.85  193.00  None  13.33  5.26  0.74  104.60
# 2020-06-13   69.33  158.93  None  12.64  4.96  0.71   87.17
# 2020-06-15   58.24  133.50  None  12.85  4.97  0.66  103.60
# 2020-06-16   53.76  120.97  None  12.66  4.79  0.65  104.77
# 2020-10-10   95.24  232.72  None   None  0.00  1.08   49.99
# 2021-12-31  223.16  366.41  None   None  0.00  2.29   16.31
# 2022-01-01  287.66  425.23  None   None  0.00  2.18   20.44
# 2022-02-01  297.88  379.54  None   None  0.00  2.23   18.97
# 2022-02-02  186.08  278.94  None   None  0.00  1.22   36.76
# 2022-03-02  219.18  300.62  None   None  0.00  2.00   19.36
# 2022-04-02   92.84  142.02  None   None  0.00  1.63   18.05
# 2022-05-02  156.05  301.50  None   None  0.00  2.39   16.90
# 2022-06-02  179.21  316.93  None   None  0.00  2.60   23.54
# 2023-08-30  129.29  205.22  None  14.52  0.02  0.35   36.30

# %%
sector_51['NO'].isin(['None']).sum()
# Out:
# 17

# %%
# Convert None into NaN
sector_51.loc[sector_51['NO'] == "None", 'NO'] = np.nan

# %%
sector_51[sector_51['NO'] == "None"]
# Out:
# Empty DataFrame
# Columns: [PM2.5, PM10, NO, NO2, NOx, CO, Ozone]
# Index: []

# %%
sector_51['NO'].value_counts(dropna=False)
# Out:
# NaN      17
# 7.99      6
# 3.00      6
# 4.35      5
# 8.02      5
#          ..
# 5.59      1
# 9.64      1
# 9.38      1
# 9.72      1
# 12.90     1
# Name: NO, Length: 993, dtype: int64

# %%
sector_51[sector_51['NO'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [PM2.5, PM10, NO, NO2, NOx, CO, Ozone]
# Index: []

# %%
(sector_51.loc["2020-06-06",'NO'])
# Out:
# nan

# %%
sector_51['NO'].isnull().sum()
# Out:
# 17

# %%
plt.figure(figsize=(20,5))
sns.lineplot(sector_51[sector_51['NO'] != "None"]['NO'])
plt.title("NO from 2020 March to 2023 November", fontsize=20)
# Out:
# <AxesSubplot: xlabel='From Date', ylabel='NO'>
# Text(0.5, 1.0, 'NO from 2020 March to 2023 November')

# %% [markdown]
# - Fill the missing values with forward fill (generally this method is used when using time series data that has no trend)

# %%
sector_51['NO'] = sector_51['NO'].ffill()
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/2575679925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51['NO'] = sector_51['NO'].ffill()

# %%
sector_51['NO'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - Now, there are no missing values

# %%
plt.figure(figsize=(14,5))
sns.lineplot(sector_51['NO'])
plt.title("NO from 2020 March to 2023 November", fontsize=20)
# Out:
# <AxesSubplot: xlabel='From Date', ylabel='NO'>
# Text(0.5, 1.0, 'NO from 2020 March to 2023 November')

# %% [markdown]
# #### 1.1.5.2 NO2 column

# %%
sector_51['NO2'].value_counts(dropna=False)
# Out:
# None     10
# 13.99     5
# 15.01     4
# 7.42      4
# 4.64      4
#          ..
# 12.05     1
# 5.59      1
# 10.52     1
# 6.66      1
# 24.28     1
# Name: NO2, Length: 1117, dtype: int64

# %%
sector_51[sector_51['NO2'] == "None"]
# Out:
#              PM2.5    PM10     NO   NO2   NOx    CO  Ozone
# From Date
# 2020-10-10   95.24  232.72  16.25  None  0.00  1.08  49.99
# 2021-12-31  223.16  366.41  13.16  None  0.00  2.29  16.31
# 2022-01-01  287.66  425.23  13.16  None  0.00  2.18  20.44
# 2022-02-01  297.88  379.54  13.16  None  0.00  2.23  18.97
# 2022-02-02  186.08  278.94  18.93  None  0.00  1.22  36.76
# 2022-03-02  219.18  300.62  18.93  None  0.00  2.00  19.36
# 2022-04-02   92.84  142.02  18.93  None  0.00  1.63  18.05
# 2022-05-02  156.05  301.50  18.93  None  0.00  2.39  16.90
# 2022-06-02  179.21  316.93  18.93  None  0.00  2.60  23.54
# 2023-08-20   83.69  132.83   3.76  None  0.11  0.48  34.72

# %%
# Convert None into NaN
sector_51.loc[sector_51['NO2'] == "None", 'NO2'] = np.nan

# %%
sector_51['NO2'].value_counts(dropna=False)
# Out:
# NaN      10
# 13.99     5
# 15.01     4
# 7.42      4
# 4.64      4
#          ..
# 12.05     1
# 5.59      1
# 10.52     1
# 6.66      1
# 24.28     1
# Name: NO2, Length: 1117, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.lineplot(sector_51[sector_51['NO2'] != "None"]['NO2'])
plt.title("NO2 from 2020 March to 2023 November", fontsize=20)
# Out:
# <AxesSubplot: xlabel='From Date', ylabel='NO2'>
# Text(0.5, 1.0, 'NO2 from 2020 March to 2023 November')

# %% [markdown]
# - Fill the missing values with forward fill (generally this method is used when using time series data that has no trend)

# %%
sector_51['NO2'] = sector_51['NO2'].ffill()
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/4006395173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51['NO2'] = sector_51['NO2'].ffill()

# %%
sector_51['NO2'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - Now, there are no missing values

# %%
plt.figure(figsize=(14,5))
sns.lineplot(sector_51['NO2'])
plt.title("NO2 from 2020 March to 2023 November", fontsize=20)
# Out:
# <AxesSubplot: xlabel='From Date', ylabel='NO2'>
# Text(0.5, 1.0, 'NO2 from 2020 March to 2023 November')

# %% [markdown]
# ### 1.1.6 Statistics and Summary

# %% [markdown]
# ### 1.1.7 Calculate AQI

# %%
import get_sub_index

# %%
sector_51
# Out:
#              PM2.5    PM10     NO    NO2    NOx    CO  Ozone
# From Date
# 2020-05-03   36.51   73.15   5.91  24.28  30.19  0.51  71.07
# 2020-06-03   22.23   39.15   5.89  23.24  29.12  0.45  55.32
# 2020-07-03   41.44   77.68   8.54  21.67  30.20  0.63  46.15
# 2020-08-03   62.64  130.39  18.77  24.16  42.94  0.86  41.67
# 2020-09-03   83.74  127.54   4.88  22.10  26.98  0.68  49.61
# ...            ...     ...    ...    ...    ...   ...    ...
# 2023-11-19  149.81  234.32  16.35  15.63  20.79  1.87  10.31
# 2023-11-20  177.53  321.96  15.10  11.77  19.21  2.51  34.88
# 2023-11-21  150.27  222.25  15.10  11.78  19.21  2.27  49.94
# 2023-11-22  173.00  281.50  15.10  11.77  19.21  1.93  49.94
# 2023-11-23  256.99  803.59  15.99  14.23  16.59  5.10  34.88
#
# [1359 rows x 7 columns]

# %%
sector_51_copy = sector_51.copy()

# %%
sector_51_copy["PM2.5_SubIndex"] = sector_51_copy["PM2.5"].apply(lambda x: get_sub_index.get_PM25_subindex(x))
sector_51_copy["PM10_SubIndex"] = sector_51_copy["PM10"].apply(lambda x: get_sub_index.get_PM10_subindex(x))
sector_51_copy["NOx_SubIndex"] = sector_51_copy["NOx"].apply(lambda x: get_sub_index.get_NOx_subindex(x))
sector_51_copy["CO_SubIndex"] = sector_51_copy["CO"].apply(lambda x: get_sub_index.get_CO_subindex(x))
sector_51_copy["Ozone_SubIndex"] = sector_51_copy["Ozone"].apply(lambda x: get_sub_index.get_O3_subindex(x))

# %%
sector_51_copy.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'CO', 'Ozone', 'PM2.5_SubIndex',
#        'PM10_SubIndex', 'NOx_SubIndex', 'CO_SubIndex', 'Ozone_SubIndex'],
#       dtype='object', name='')

# %%
sector_51_copy = sector_51_copy[['PM2.5', 'PM2.5_SubIndex', 'PM10', 'PM10_SubIndex', 'NO', 'NO2', 
                'NOx', 'NOx_SubIndex','CO', 'CO_SubIndex', 'Ozone', 'Ozone_SubIndex']]

# %%
sector_51_copy
# Out:
#              PM2.5  PM2.5_SubIndex    PM10  PM10_SubIndex     NO    NO2  \
# From Date
# 2020-05-03   36.51       60.850000   73.15      73.150000   5.91  24.28
# 2020-06-03   22.23       37.050000   39.15      39.150000   5.89  23.24
# 2020-07-03   41.44       69.066667   77.68      77.680000   8.54  21.67
# 2020-08-03   62.64      108.800000  130.39     120.260000  18.77  24.16
# 2020-09-03   83.74      179.133333  127.54     118.360000   4.88  22.10
# ...            ...             ...     ...            ...    ...    ...
# 2023-11-19  149.81      322.930769  234.32     189.546667  16.35  15.63
# 2023-11-20  177.53      344.253846  321.96     271.960000  15.10  11.77
# 2023-11-21  150.27      323.284615  222.25     181.500000  15.10  11.78
# 2023-11-22  173.00      340.769231  281.50     231.500000  15.10  11.77
# 2023-11-23  256.99      405.376923  803.59     866.987500  15.99  14.23
#
#               NOx  NOx_SubIndex    CO  CO_SubIndex  Ozone  Ozone_SubIndex  \
# From Date
# 2020-05-03  30.19       37.7375  0.51       25.500  71.07           71.07
# 2020-06-03  29.12       36.4000  0.45       22.500  55.32           55.32
# 2020-07-03  30.20       37.7500  0.63       31.500  46.15           46.15
# 2020-08-03  42.94       53.6750  0.86       43.000  41.67           41.67
# 2020-09-03  26.98       33.7250  0.68       34.000  49.61           49.61
# ...           ...           ...   ...          ...    ...             ...
# 2023-11-19  20.79       25.9875  1.87       93.500  10.31           10.31
# 2023-11-20  19.21       24.0125  2.51      106.375  34.88           34.88
# 2023-11-21  19.21       24.0125  2.27      103.375  49.94           49.94
# 2023-11-22  19.21       24.0125  1.93       96.500  49.94           49.94
# 2023-11-23  16.59       20.7375  5.10      138.750  34.88           34.88
#
#             Checks    AQI
# From Date
# 2020-05-03       5   73.0
# 2020-06-03       5   55.0
# 2020-07-03       5   78.0
# 2020-08-03       5  120.0
# 2020-09-03       5  179.0
# ...            ...    ...
# 2023-11-19       5  323.0
# 2023-11-20       5  344.0
# 2023-11-21       5  323.0
# 2023-11-22       5  341.0
# 2023-11-23       5  867.0
#
# [1359 rows x 14 columns]

# %%
sector_51_copy[datetime(2023,10,30):]
# Out:
#              PM2.5  PM2.5_SubIndex    PM10  PM10_SubIndex      NO     NO2  \
# From Date
# 2023-10-30  106.16      253.866667  171.23     147.486667   18.13   72.35
# 2023-10-31  163.24      333.261538  252.50     202.500000    7.58   79.73
# 2023-01-11   90.80      202.666667  156.81     137.873333   40.16   69.99
# 2023-02-11  169.72      338.246154  295.43     245.430000  121.61   89.89
# 2023-03-11  311.11      447.007692  335.01     285.010000   64.47   86.39
# 2023-04-11  357.39      482.607692  640.62     663.275000   55.81   89.20
# 2023-05-11  172.64      340.492308  390.40     350.500000   68.11  128.49
# 2023-06-11  297.54      436.569231  455.15     431.437500    6.12   35.39
# 2023-07-11  222.18      378.600000  421.06     388.825000   81.22   87.72
# 2023-08-11  302.78      440.600000  419.93     387.412500  166.83  176.38
# 2023-09-11  342.28      470.984615  532.25     527.812500   21.78   64.41
# 2023-10-11  123.29      302.530769  205.12     170.080000   50.95   74.56
# 2023-11-11  121.53      301.176923  198.35     165.566667   39.01   57.53
# 2023-12-11  150.01      323.084615  221.22     180.813333   26.83   46.19
# 2023-11-13  307.18      443.984615  413.21     379.012500   20.60   11.97
# 2023-11-14  255.45      404.192308  382.83     341.037500   41.01   46.24
# 2023-11-15  185.14      350.107692  347.84     297.840000   53.57   42.98
# 2023-11-16  399.47      514.976923  460.70     438.375000   45.60   45.84
# 2023-11-17  253.84      402.953846  438.72     410.900000  130.01   75.42
# 2023-11-18  165.80      335.230769  284.23     234.230000   42.40   66.68
# 2023-11-19  149.81      322.930769  234.32     189.546667   16.35   15.63
# 2023-11-20  177.53      344.253846  321.96     271.960000   15.10   11.77
# 2023-11-21  150.27      323.284615  222.25     181.500000   15.10   11.78
# 2023-11-22  173.00      340.769231  281.50     231.500000   15.10   11.77
# 2023-11-23  256.99      405.376923  803.59     866.987500   15.99   14.23
#
#                NOx  NOx_SubIndex    CO  CO_SubIndex  Ozone  Ozone_SubIndex  \
# From Date
# 2023-10-30   44.23       55.2875  1.48       74.000  30.17           30.17
# 2023-10-31   46.53       58.1625  1.57       78.500  44.34           44.34
# 2023-01-11   58.54       73.1750  2.04      100.500  30.18           30.18
# 2023-02-11   98.44      118.4400  3.39      117.375  30.39           30.39
# 2023-03-11   61.14       76.4250  3.32      116.500  30.99           30.99
# 2023-04-11   70.45       88.0625  4.03      125.375  35.86           35.86
# 2023-05-11  100.80      120.8000  3.28      116.000  17.54           17.54
# 2023-06-11   18.96       23.7000  3.48      118.500  20.89           20.89
# 2023-07-11  103.38      123.3800  4.07      125.875  20.99           20.99
# 2023-08-11  146.43      166.4300  4.61      132.625  26.93           26.93
# 2023-09-11   29.04       36.3000  3.73      121.625  19.78           19.78
# 2023-10-11   63.84       79.8000  2.54      106.750  12.80           12.80
# 2023-11-11   44.87       56.0875  2.49      106.125  15.64           15.64
# 2023-12-11   32.74       40.9250  2.73      109.125  23.08           23.08
# 2023-11-13   33.04       41.3000  3.64      120.500  10.67           10.67
# 2023-11-14   51.60       64.5000  4.47      130.875  10.30           10.30
# 2023-11-15   47.47       59.3375  3.11      113.875  10.41           10.41
# 2023-11-16   34.66       43.3250  2.82      110.250  10.34           10.34
# 2023-11-17   77.08       96.3500  3.27      115.875  10.30           10.30
# 2023-11-18   42.47       53.0875  1.95       97.500  10.31           10.31
# 2023-11-19   20.79       25.9875  1.87       93.500  10.31           10.31
# 2023-11-20   19.21       24.0125  2.51      106.375  34.88           34.88
# 2023-11-21   19.21       24.0125  2.27      103.375  49.94           49.94
# 2023-11-22   19.21       24.0125  1.93       96.500  49.94           49.94
# 2023-11-23   16.59       20.7375  5.10      138.750  34.88           34.88
#
#             Checks    AQI
# From Date
# 2023-10-30       5  254.0
# 2023-10-31       5  333.0
# 2023-01-11       5  203.0
# 2023-02-11       5  338.0
# 2023-03-11       5  447.0
# 2023-04-11       5  663.0
# 2023-05-11       5  350.0
# 2023-06-11       5  437.0
# 2023-07-11       5  389.0
# 2023-08-11       5  441.0
# 2023-09-11       5  528.0
# 2023-10-11       5  303.0
# 2023-11-11       5  301.0
# 2023-12-11       5  323.0
# 2023-11-13       5  444.0
# 2023-11-14       5  404.0
# 2023-11-15       5  350.0
# 2023-11-16       5  515.0
# 2023-11-17       5  411.0
# 2023-11-18       5  335.0
# 2023-11-19       5  323.0
# 2023-11-20       5  344.0
# 2023-11-21       5  323.0
# 2023-11-22       5  341.0
# 2023-11-23       5  867.0

# %% [markdown]
# - ### From Nov 13 onwards month and day has been inverted

# %%
sector_51_copy[datetime(2023,11,11):]
# Out:
#              PM2.5  PM2.5_SubIndex    PM10  PM10_SubIndex      NO    NO2  \
# From Date
# 2023-11-11  121.53      301.176923  198.35     165.566667   39.01  57.53
# 2023-12-11  150.01      323.084615  221.22     180.813333   26.83  46.19
# 2023-11-13  307.18      443.984615  413.21     379.012500   20.60  11.97
# 2023-11-14  255.45      404.192308  382.83     341.037500   41.01  46.24
# 2023-11-15  185.14      350.107692  347.84     297.840000   53.57  42.98
# 2023-11-16  399.47      514.976923  460.70     438.375000   45.60  45.84
# 2023-11-17  253.84      402.953846  438.72     410.900000  130.01  75.42
# 2023-11-18  165.80      335.230769  284.23     234.230000   42.40  66.68
# 2023-11-19  149.81      322.930769  234.32     189.546667   16.35  15.63
# 2023-11-20  177.53      344.253846  321.96     271.960000   15.10  11.77
# 2023-11-21  150.27      323.284615  222.25     181.500000   15.10  11.78
# 2023-11-22  173.00      340.769231  281.50     231.500000   15.10  11.77
# 2023-11-23  256.99      405.376923  803.59     866.987500   15.99  14.23
#
#               NOx  NOx_SubIndex    CO  CO_SubIndex  Ozone  Ozone_SubIndex  \
# From Date
# 2023-11-11  44.87       56.0875  2.49      106.125  15.64           15.64
# 2023-12-11  32.74       40.9250  2.73      109.125  23.08           23.08
# 2023-11-13  33.04       41.3000  3.64      120.500  10.67           10.67
# 2023-11-14  51.60       64.5000  4.47      130.875  10.30           10.30
# 2023-11-15  47.47       59.3375  3.11      113.875  10.41           10.41
# 2023-11-16  34.66       43.3250  2.82      110.250  10.34           10.34
# 2023-11-17  77.08       96.3500  3.27      115.875  10.30           10.30
# 2023-11-18  42.47       53.0875  1.95       97.500  10.31           10.31
# 2023-11-19  20.79       25.9875  1.87       93.500  10.31           10.31
# 2023-11-20  19.21       24.0125  2.51      106.375  34.88           34.88
# 2023-11-21  19.21       24.0125  2.27      103.375  49.94           49.94
# 2023-11-22  19.21       24.0125  1.93       96.500  49.94           49.94
# 2023-11-23  16.59       20.7375  5.10      138.750  34.88           34.88
#
#             Checks    AQI
# From Date
# 2023-11-11       5  301.0
# 2023-12-11       5  323.0
# 2023-11-13       5  444.0
# 2023-11-14       5  404.0
# 2023-11-15       5  350.0
# 2023-11-16       5  515.0
# 2023-11-17       5  411.0
# 2023-11-18       5  335.0
# 2023-11-19       5  323.0
# 2023-11-20       5  344.0
# 2023-11-21       5  323.0
# 2023-11-22       5  341.0
# 2023-11-23       5  867.0

# %%
sector_51_copy["Checks"] = (sector_51_copy["PM2.5_SubIndex"] > 0).astype(int) + \
                (sector_51_copy["PM10_SubIndex"] > 0).astype(int) + \
                (sector_51_copy["NOx_SubIndex"] > 0).astype(int) + \
                (sector_51_copy["CO_SubIndex"] > 0).astype(int) + \
                (sector_51_copy["Ozone_SubIndex"] > 0).astype(int)

sector_51_copy["AQI"] = round(sector_51_copy[["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", "CO_SubIndex", "Ozone_SubIndex"]].max(axis = 1))
sector_51_copy.loc[sector_51_copy["PM2.5_SubIndex"] + sector_51_copy["PM10_SubIndex"] <= 0, "AQI"] = np.NaN
sector_51_copy.loc[sector_51_copy.Checks < 3, "AQI"] = np.NaN
# Out:
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/913560530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51_copy["Checks"] = (sector_51_copy["PM2.5_SubIndex"] > 0).astype(int) + \
# /var/folders/27/b03t8q596qvcmtyqjtnh0w6w0000gn/T/ipykernel_28342/913560530.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sector_51_copy["AQI"] = round(sector_51_copy[["PM2.5_SubIndex", "PM10_SubIndex", "NOx_SubIndex", "CO_SubIndex", "Ozone_SubIndex"]].max(axis = 1))

# %%
sector_51_copy
# Out:
#              PM2.5  PM2.5_SubIndex    PM10  PM10_SubIndex     NO    NO2  \
# From Date
# 2020-05-03   36.51       60.850000   73.15      73.150000   5.91  24.28
# 2020-06-03   22.23       37.050000   39.15      39.150000   5.89  23.24
# 2020-07-03   41.44       69.066667   77.68      77.680000   8.54  21.67
# 2020-08-03   62.64      108.800000  130.39     120.260000  18.77  24.16
# 2020-09-03   83.74      179.133333  127.54     118.360000   4.88  22.10
# ...            ...             ...     ...            ...    ...    ...
# 2023-11-19  149.81      322.930769  234.32     189.546667  16.35  15.63
# 2023-11-20  177.53      344.253846  321.96     271.960000  15.10  11.77
# 2023-11-21  150.27      323.284615  222.25     181.500000  15.10  11.78
# 2023-11-22  173.00      340.769231  281.50     231.500000  15.10  11.77
# 2023-11-23  256.99      405.376923  803.59     866.987500  15.99  14.23
#
#               NOx  NOx_SubIndex    CO  CO_SubIndex  Ozone  Ozone_SubIndex  \
# From Date
# 2020-05-03  30.19       37.7375  0.51       25.500  71.07           71.07
# 2020-06-03  29.12       36.4000  0.45       22.500  55.32           55.32
# 2020-07-03  30.20       37.7500  0.63       31.500  46.15           46.15
# 2020-08-03  42.94       53.6750  0.86       43.000  41.67           41.67
# 2020-09-03  26.98       33.7250  0.68       34.000  49.61           49.61
# ...           ...           ...   ...          ...    ...             ...
# 2023-11-19  20.79       25.9875  1.87       93.500  10.31           10.31
# 2023-11-20  19.21       24.0125  2.51      106.375  34.88           34.88
# 2023-11-21  19.21       24.0125  2.27      103.375  49.94           49.94
# 2023-11-22  19.21       24.0125  1.93       96.500  49.94           49.94
# 2023-11-23  16.59       20.7375  5.10      138.750  34.88           34.88
#
#             Checks    AQI
# From Date
# 2020-05-03       5   73.0
# 2020-06-03       5   55.0
# 2020-07-03       5   78.0
# 2020-08-03       5  120.0
# 2020-09-03       5  179.0
# ...            ...    ...
# 2023-11-19       5  323.0
# 2023-11-20       5  344.0
# 2023-11-21       5  323.0
# 2023-11-22       5  341.0
# 2023-11-23       5  867.0
#
# [1359 rows x 14 columns]

# %%
sns.displot(sector_51_copy['AQI'])

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from datetime import datetime, timedelta
from statsmodels.tsa.arima.model import ARIMA 
from statsmodels.tsa.statespace.sarimax import SARIMAX

from pmdarima import auto_arima
import statsmodels.api as sm

# %%
acf_plot = plot_acf(sector_51_copy['AQI'], lags= 100)

# %%
pacf_plot = plot_pacf(sector_51_copy['AQI'], lags= 100)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
import statsmodels.api as sm
decomp = sm.tsa.seasonal_decompose(sector_51_copy['AQI'])
_ = decomp.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [197], line 2
#       1 import statsmodels.api as sm
# ----> 2 decomp = sm.tsa.seasonal_decompose(sector_51_copy['AQI'], model='additive')
#       3 _ = decomp.plot()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
#     164     raise ValueError(
#     165         f"x must have 2 complete cycles requires {2 * pfreq} "
#     166         f"observations. x only has {x.shape[0]} observation(s)"
#     167     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %%
sector_51_copy.index
# Out:
# DatetimeIndex(['2020-05-03', '2020-06-03', '2020-07-03', '2020-08-03',
#                '2020-09-03', '2020-10-03', '2020-11-03', '2020-12-03',
#                '2020-03-13', '2020-03-14',
#                ...
#                '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17',
#                '2023-11-18', '2023-11-19', '2023-11-20', '2023-11-21',
#                '2023-11-22', '2023-11-23'],
#               dtype='datetime64[ns]', name='From Date', length=1359, freq=None)

# %%
sector_51_copy.index.set_names([None])
# Out:
# DatetimeIndex(['2020-05-03', '2020-06-03', '2020-07-03', '2020-08-03',
#                '2020-09-03', '2020-10-03', '2020-11-03', '2020-12-03',
#                '2020-03-13', '2020-03-14',
#                ...
#                '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17',
#                '2023-11-18', '2023-11-19', '2023-11-20', '2023-11-21',
#                '2023-11-22', '2023-11-23'],
#               dtype='datetime64[ns]', length=1359, freq=None)

# %%
sector_51_copy['AQI'].index = sector_51_copy['AQI'].index.set_names([None])

# %%
sector_51_copy['AQI'].index
# Out:
# DatetimeIndex(['2020-05-03', '2020-06-03', '2020-07-03', '2020-08-03',
#                '2020-09-03', '2020-10-03', '2020-11-03', '2020-12-03',
#                '2020-03-13', '2020-03-14',
#                ...
#                '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17',
#                '2023-11-18', '2023-11-19', '2023-11-20', '2023-11-21',
#                '2023-11-22', '2023-11-23'],
#               dtype='datetime64[ns]', length=1359, freq=None)

# %%
# random forest and nn aqi_pred

# %%
train_end = datetime(2023, 8, 10)
test_end = datetime(2023, 9, 10)

train_data = sector_51_copy[:train_end]['AQI']
test_data = sector_51_copy[train_end + timedelta(days=1):test_end]['AQI']

# %%
train_data
# Out:
# From Date
# 2020-05-03     73.0
# 2020-06-03     55.0
# 2020-07-03     78.0
# 2020-08-03    120.0
# 2020-09-03    179.0
#               ...
# 2023-04-10    338.0
# 2023-05-10    358.0
# 2023-06-10    346.0
# 2023-07-10    283.0
# 2023-08-10    260.0
# Name: AQI, Length: 1313, dtype: float64

# %%
test_data
# Out:
# Series([], Name: AQI, dtype: float64)

# %% [markdown]
# ### ROlling

# %%
my_order = (1, 0, 1)
p,d,q = my_order
rolling_predictions = test_data.copy()
for train_end in test_data.index:
    print("train_end-timedelta(days=1)", train_end - timedelta(days=1))
    train_data = sector_51_copy[:train_end - timedelta(days=1)]['AQI']

#     model = ARIMA(train_data, order=my_order)
#     model_fit = model.fit()
#     pred = model_fit.forecast()
#     print("pred", pred)
#     rolling_predictions[train_end] = pred
# Out:
# train_end-timedelta(days=1) 2023-10-22 00:00:00
# train_end-timedelta(days=1) 2023-10-23 00:00:00
# train_end-timedelta(days=1) 2023-10-24 00:00:00
# train_end-timedelta(days=1) 2023-10-25 00:00:00
# train_end-timedelta(days=1) 2023-10-26 00:00:00
# train_end-timedelta(days=1) 2023-10-27 00:00:00
# train_end-timedelta(days=1) 2023-10-28 00:00:00
# train_end-timedelta(days=1) 2023-10-29 00:00:00
# train_end-timedelta(days=1) 2023-10-30 00:00:00
# train_end-timedelta(days=1) 2023-01-10 00:00:00
# train_end-timedelta(days=1) 2023-02-10 00:00:00
# train_end-timedelta(days=1) 2023-03-10 00:00:00
# train_end-timedelta(days=1) 2023-04-10 00:00:00
# train_end-timedelta(days=1) 2023-05-10 00:00:00
# train_end-timedelta(days=1) 2023-06-10 00:00:00
# train_end-timedelta(days=1) 2023-07-10 00:00:00
# train_end-timedelta(days=1) 2023-08-10 00:00:00
# train_end-timedelta(days=1) 2023-09-10 00:00:00
# train_end-timedelta(days=1) 2023-10-10 00:00:00
# train_end-timedelta(days=1) 2023-11-10 00:00:00
# train_end-timedelta(days=1) 2023-12-10 00:00:00
# train_end-timedelta(days=1) 2023-11-12 00:00:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1699747200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2023-11-12 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#
# KeyError: Timestamp('2023-11-12 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [261], line 6
#       4 for train_end in test_data.index:
#       5     print("train_end-timedelta(days=1)", train_end - timedelta(days=1))
# ----> 6     train_data = sector_51_copy[:train_end - timedelta(days=1)]['AQI']
#       8 #     model = ARIMA(train_data, order=my_order)
#       9 #     model_fit = model.fit()
#      10 #     pred = model_fit.forecast()
#      11 #     print("pred", pred)
#      12 #     rolling_predictions[train_end] = pred
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3779, in DataFrame.__getitem__(self, key)
#    3777         return self._getitem_multilevel(key)
#    3778 # Do we have a slicer (on rows)?
# -> 3779 indexer = convert_to_index_sliceable(self, key)
#    3780 if indexer is not None:
#    3781     if isinstance(indexer, np.ndarray):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:2494, in convert_to_index_sliceable(obj, key)
#    2492 idx = obj.index
#    2493 if isinstance(key, slice):
# -> 2494     return idx._convert_slice_indexer(key, kind="getitem")
#    2496 elif isinstance(key, str):
#    2497
#    2498     # we are an actual column
#    2499     if key in obj.columns:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:4284, in Index._convert_slice_indexer(self, key, kind)
#    4282     indexer = key
#    4283 else:
# -> 4284     indexer = self.slice_indexer(start, stop, step)
#    4286 return indexer
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:809, in DatetimeIndex.slice_indexer(self, start, end, step, kind)
#     801 # GH#33146 if start and end are combinations of str and None and Index is not
#     802 # monotonic, we can not use Index.slice_indexer because it does not honor the
#     803 # actual elements, is only searching for start and end
#     804 if (
#     805     check_str_or_none(start)
#     806     or check_str_or_none(end)
#     807     or self.is_monotonic_increasing
#     808 ):
# --> 809     return Index.slice_indexer(self, start, end, step, kind=kind)
#     811 mask = np.array(True)
#     812 deprecation_mask = np.array(True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    6516 """
#    6517 Compute the slice indexer for input labels and step.
#    6518
#    (...)
#    6555 slice(1, 3, None)
#    6556 """
#    6557 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6559 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6561 # return a slice
#    6562 if not is_scalar(start_slice):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6773, in Index.slice_locs(self, start, end, step, kind)
#    6771 end_slice = None
#    6772 if end is not None:
# -> 6773     end_slice = self.get_slice_bound(end, "right")
#    6774 if end_slice is None:
#    6775     end_slice = len(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6686, in Index.get_slice_bound(self, label, side, kind)
#    6683         return self._searchsorted_monotonic(label, side)
#    6684     except ValueError:
#    6685         # raise the original KeyError
# -> 6686         raise err
#    6688 if isinstance(slc, np.ndarray):
#    6689     # get_loc may return a boolean array, which
#    6690     # is OK as long as they are representable by a slice.
#    6691     assert is_bool_dtype(slc.dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6680, in Index.get_slice_bound(self, label, side, kind)
#    6678 # we need to look up the label
#    6679 try:
# -> 6680     slc = self.get_loc(label)
#    6681 except KeyError as err:
#    6682     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: Timestamp('2023-11-12 00:00:00')

# %% [markdown]
# ### Wihout rolling

# %%
my_order = (1,0,1)
my_seasonal_order = (0, 0, 0, 0) 
# define model
model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
model_fit = model.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.60943D+00    |proj g|=  4.27071D-02
#
# At iterate    5    f=  5.60765D+00    |proj g|=  3.02992D-03
#
# At iterate   10    f=  5.60746D+00    |proj g|=  2.99696D-04
#
# At iterate   15    f=  5.60745D+00    |proj g|=  4.01404D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     22      1     0     0   9.142D-06   5.607D+00
#   F =   5.6074460058167261
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
test_data.index
# Out:
# DatetimeIndex(['2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26',
#                '2023-10-27', '2023-10-28', '2023-10-29', '2023-10-30',
#                '2023-10-31', '2023-01-11', '2023-02-11', '2023-03-11',
#                '2023-04-11', '2023-05-11', '2023-06-11', '2023-07-11',
#                '2023-08-11', '2023-09-11', '2023-10-11', '2023-11-11',
#                '2023-12-11', '2023-11-13', '2023-11-14', '2023-11-15',
#                '2023-11-16', '2023-11-17', '2023-11-18', '2023-11-19',
#                '2023-11-20', '2023-11-21', '2023-11-22'],
#               dtype='datetime64[ns]', name='From Date', freq=None)

# %%
pd.Series(model_fit.forecast(len(test_data)), index = test_data.index)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# From Date
# 2023-10-23   NaN
# 2023-10-24   NaN
# 2023-10-25   NaN
# 2023-10-26   NaN
# 2023-10-27   NaN
# 2023-10-28   NaN
# 2023-10-29   NaN
# 2023-10-30   NaN
# 2023-10-31   NaN
# 2023-01-11   NaN
# 2023-02-11   NaN
# 2023-03-11   NaN
# 2023-04-11   NaN
# 2023-05-11   NaN
# 2023-06-11   NaN
# 2023-07-11   NaN
# 2023-08-11   NaN
# 2023-09-11   NaN
# 2023-10-11   NaN
# 2023-11-11   NaN
# 2023-12-11   NaN
# 2023-11-13   NaN
# 2023-11-14   NaN
# 2023-11-15   NaN
# 2023-11-16   NaN
# 2023-11-17   NaN
# 2023-11-18   NaN
# 2023-11-19   NaN
# 2023-11-20   NaN
# 2023-11-21   NaN
# 2023-11-22   NaN
# Name: predicted_mean, dtype: float64

# %%
predictions = model_fit.forecast(len(test_data))
predictions = pd.Series(predictions, index=test_data.index)
residuals = test_data - predictions
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
test_data.values - model_fit.forecast(len(test_data)).values
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# array([-116.01929076,  -89.12915821,   19.64760352,   34.31317653,
#          43.86970094,   40.31927566,  -65.33604077,  -13.09422945,
#          71.04668965,  -53.91134153,   86.03358156,  199.88332682,
#         420.63972619,  112.30457636,  203.87963942,  160.36664356,
#         216.76728371,  308.08322216,   87.31608921,   89.46748379,
#         115.53897405,  240.53209795,  204.44836385,  154.28925109,
#         323.05621052,  222.75066508,  150.37401031,  141.92761489,
#         166.41282116,  148.83094562,  170.18327944])

# %%
plt.plot(test_data.values - model_fit.forecast(len(test_data)).values)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
predictions
# Out:
# From Date
# 2023-10-23   NaN
# 2023-10-24   NaN
# 2023-10-25   NaN
# 2023-10-26   NaN
# 2023-10-27   NaN
# 2023-10-28   NaN
# 2023-10-29   NaN
# 2023-10-30   NaN
# 2023-10-31   NaN
# 2023-01-11   NaN
# 2023-02-11   NaN
# 2023-03-11   NaN
# 2023-04-11   NaN
# 2023-05-11   NaN
# 2023-06-11   NaN
# 2023-07-11   NaN
# 2023-08-11   NaN
# 2023-09-11   NaN
# 2023-10-11   NaN
# 2023-11-11   NaN
# 2023-12-11   NaN
# 2023-11-13   NaN
# 2023-11-14   NaN
# 2023-11-15   NaN
# 2023-11-16   NaN
# 2023-11-17   NaN
# 2023-11-18   NaN
# 2023-11-19   NaN
# 2023-11-20   NaN
# 2023-11-21   NaN
# 2023-11-22   NaN
# Name: predicted_mean, dtype: float64

# %%
residuals
# Out:
# From Date
# 2023-10-23   NaN
# 2023-10-24   NaN
# 2023-10-25   NaN
# 2023-10-26   NaN
# 2023-10-27   NaN
# 2023-10-28   NaN
# 2023-10-29   NaN
# 2023-10-30   NaN
# 2023-10-31   NaN
# 2023-01-11   NaN
# 2023-02-11   NaN
# 2023-03-11   NaN
# 2023-04-11   NaN
# 2023-05-11   NaN
# 2023-06-11   NaN
# 2023-07-11   NaN
# 2023-08-11   NaN
# 2023-09-11   NaN
# 2023-10-11   NaN
# 2023-11-11   NaN
# 2023-12-11   NaN
# 2023-11-13   NaN
# 2023-11-14   NaN
# 2023-11-15   NaN
# 2023-11-16   NaN
# 2023-11-17   NaN
# 2023-11-18   NaN
# 2023-11-19   NaN
# 2023-11-20   NaN
# 2023-11-21   NaN
# 2023-11-22   NaN
# dtype: float64

# %%
plt.figure(figsize=(14, 7))
plt.plot(test_data)
plt.plot(predictions, '--')
plt.legend(('Data', 'Predictions'), fontsize=16)
plt.title("Sector 51 AQI daily SARIMAX" + str(my_order) + str(my_seasonal_order) )
# Out:
# Text(0.5, 1.0, 'Sector 51 AQI daily SARIMAX(1, 0, 1)(1, 0, 1, 365)')

# %% [markdown]
# - ## Note: We are not taking 24 hour average to compute AQI because our data is itself daily data.

# %%
get_sub_index.get_CO_subindex()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [172], line 1
# ----> 1 get_sub_index.get_CO_subindex()
#
# TypeError: get_CO_subindex() missing 1 required positional argument: 'x'

# %% [markdown]
# ## 1.2 Vikas Sadan

# %% [markdown]
# ## 1.3 NISE

# %% [markdown]
# ## 1.4 Teri Gram

# %% [markdown]
# # 2. EDA

# %% [markdown]
# # 3. Compute AQI

# %% [markdown]
# # 4. Time Series
